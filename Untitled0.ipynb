# %% [markdown]
# <a href="https://colab.research.google.com/github/gapalfaro-cmyk/Proyecto-de-fin-de-modulo-8---Alfaro-Badillo-Cruz-Perez-Rupit/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
proyecto-sequia-mx-2026/
├─ data/
│  ├─ sequia_municipal_enero.csv
│  ├─ vulnerabilidad_ambiental_municipal.csv
│  ├─ vulnerabilidad_economica_municipal.csv
│  ├─ vulnerabilidad_social_municipal.csv
│  └─ municipios.shp
├─ src/
│  ├─ 01_carga_limpieza.py
│  ├─ 02_eda.py
│  ├─ 03_clustering_sequia.py
│  ├─ 04_clustering_riesgo.py
│  ├─ 05_dashboard.py
├─ site/
│  ├─ index.html
│  ├─ datos_metodologia.html
│  ├─ resultados_descriptivos.html
│  ├─ clusters_riesgo.html
│  └─ conclusiones.html
├─ reporte/
│  └─ reporte_proyecto.md
└─ README.md
